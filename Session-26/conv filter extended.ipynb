# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img

# %%
img = np.array(load_img("../datasets/mon.jpg", target_size=(200, 200)))

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
img_grey = img.mean(axis=2)

# %%
plt.imshow(img_grey,cmap="gray")

# %%
fil = np.array([[1,0,-1],
                [1,0,-1],
                [1,0,-1]])

# %%
fil
# Out:
# array([[ 1,  0, -1],
#        [ 1,  0, -1],
#        [ 1,  0, -1]])

# %%
img_grey.shape
# Out:
# (200, 200)

# %%
padded_img.shape
# Out:
# (202, 202)

# %%
result.shape
# Out:
# (200, 200)

# %%
def applyFilter(img_grey,fil):
    padded_img = np.pad(img_grey,1)
    result = np.empty_like(img_grey)
    for row in range(result.shape[0]):
        for col in range(result.shape[1]):
            cut = padded_img[row:row+3,col:col+3]
            result[row,col] = np.absolute(np.mean(fil*cut))
    return  result

# %%
plt.imshow(applyFilter(img_grey,fil),cmap="gray")

# %%
plt.imshow(applyFilter(img_grey,fil.T),cmap="gray")
