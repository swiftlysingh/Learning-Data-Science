# %%
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
from tensorflow.keras.layers import Input,Dense,Reshape,Flatten,Conv2D,MaxPool2D
from tensorflow.keras.models import Model

# %%
in_layer = Input(shape=(28,28))
reshaped = Reshape(target_shape=(28,28,1))(in_layer)
conv = Conv2D(filters=60,kernel_size=3)(reshaped)
pooling = MaxPool2D()(conv)
conv = Conv2D(filters=60,kernel_size=3)(pooling)
pooling = MaxPool2D()(conv)
conv = Conv2D(filters=60,kernel_size=3)(pooling)
pooling = MaxPool2D()(conv)
flat = Flatten()(pooling)
d1 = Dense(units=400,activation="tanh")(flat)
d2 = Dense(units=100,activation="tanh")(d1)
out_layer = Dense(units=10,activation="softmax")(d2)

# %%
model = Model(in_layer,out_layer)

# %%
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# reshape_4 (Reshape)          (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 26, 26, 60)        600
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 13, 13, 60)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 11, 11, 60)        32460
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 5, 5, 60)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 3, 3, 60)          32460
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 1, 1, 60)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 60)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 400)               24400
# _________________________________________________________________
# dense_10 (Dense)             (None, 100)               40100
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 131,030
# Trainable params: 131,030
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit(x_train, to_categorical(y_train, num_classes=10), batch_size=1000, epochs=10)
# Out:
# Epoch 1/10
# 60/60 [==============================] - 22s 373ms/step - loss: 0.6950 - accuracy: 0.8012
# Epoch 2/10
# 60/60 [==============================] - 24s 395ms/step - loss: 0.1708 - accuracy: 0.9510
# Epoch 3/10
# 60/60 [==============================] - 26s 427ms/step - loss: 0.1150 - accuracy: 0.9667
# Epoch 4/10
# 60/60 [==============================] - 25s 416ms/step - loss: 0.0885 - accuracy: 0.9743
# Epoch 5/10
# 60/60 [==============================] - 33s 557ms/step - loss: 0.0744 - accuracy: 0.9777
# Epoch 6/10
# 60/60 [==============================] - 27s 442ms/step - loss: 0.0650 - accuracy: 0.9808
# Epoch 7/10
# 60/60 [==============================] - 26s 432ms/step - loss: 0.0595 - accuracy: 0.9819
# Epoch 8/10
# 60/60 [==============================] - 25s 410ms/step - loss: 0.0534 - accuracy: 0.9840
# Epoch 9/10
# 60/60 [==============================] - 24s 395ms/step - loss: 0.0492 - accuracy: 0.9845
# Epoch 10/10
# 60/60 [==============================] - 24s 403ms/step - loss: 0.0411 - accuracy: 0.9878

# %%
5
model.evaluate(x_test, to_categorical(y_test, num_classes=10))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0640 - accuracy: 0.9803
# [0.06396158784627914, 0.9803000092506409]
